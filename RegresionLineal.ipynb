# %% [markdown]
# EJERCICIO REGRESION LOGISTICA

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("/Users/Maira/Downloads/framingham.csv")

# %%
data.head(10)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
# 5     0   43        2.0              0         0.0     0.0                0
# 6     0   63        1.0              0         0.0     0.0                0
# 7     0   45        2.0              1        20.0     0.0                0
# 8     1   52        1.0              0         0.0     0.0                0
# 9     1   43        1.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# ...

# %%
data.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
data.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
data.info(null_counts=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   male             int64
#  1   age              int64
#  2   education        float64
#  3   currentSmoker    int64
#  4   cigsPerDay       float64
#  5   BPMeds           float64
#  6   prevalentStroke  int64
#  7   prevalentHyp     int64
#  8   diabetes         int64
#  9   totChol          float64
#  10  sysBP            float64
#  11  diaBP            float64
#  12  BMI              float64
#  13  heartRate        float64
#  14  glucose          float64
#  15  TenYearCHD       int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB
# C:\Users\Maira\AppData\Local\Temp\ipykernel_7056\3229445148.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   data.info(null_counts=False)

# %%
data = data.fillna(data.mean())

# %%
data.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
data.shape
# Out:
# (4238, 16)

# %%
data.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
data.corr()
# Out:
#                      male       age  education  currentSmoker  cigsPerDay  \
# male             1.000000 -0.028979   0.017352       0.197596    0.317930
# age             -0.028979  1.000000  -0.165883      -0.213748   -0.192791
# education        0.017352 -0.165883   1.000000       0.018532    0.008085
# currentSmoker    0.197596 -0.213748   0.018532       1.000000    0.769690
# cigsPerDay       0.317930 -0.192791   0.008085       0.769690    1.000000
# BPMeds          -0.052506  0.122995  -0.010815      -0.048938   -0.046134
# prevalentStroke -0.004546  0.057655  -0.035112      -0.032988   -0.032707
# prevalentHyp     0.005313  0.307194  -0.081970      -0.103260   -0.066146
# diabetes         0.015708  0.101258  -0.038680      -0.044295   -0.037067
# totChol         -0.070322  0.262131  -0.023115      -0.046562   -0.026320
# sysBP           -0.035989  0.394302  -0.129631      -0.130230   -0.088780
# diaBP            0.057933  0.206104  -0.062316      -0.107746   -0.056632
# ...

# %%
plt.figure(dpi=150)
sns.heatmap(data.corr(),annot=False)
# Out:
# <Axes: >

# %%
data.dtypes.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of male                 int64
# age                  int64
# education          float64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object>

# %%
# convertir el tipo de datos de la columna 'educación' en valores numéricos
data["education"] = pd.to_numeric(data["education"], errors='coerce')
data = data.dropna()

# %%
x = data.drop("TenYearCHD", axis=1)
x.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose'],
#       dtype='object')

# %%
y = data['TenYearCHD']

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4231    0
# 4232    1
# 4233    1
# 4234    0
# 4237    0
# Name: TenYearCHD, Length: 3656, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split( x, y,test_size= .3
                                                 ,random_state= 42 ,
                                                 stratify= y )

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
print(data.shape)
# Out:
# (2559, 15)
# (2559,)
# (1097, 15)
# (1097,)
# (3656, 16)

# %%
# escalar los datos usando MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
# usar el clasificador de regresión logística para entrenar los datos y probar el modelo
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
model = lg.fit(x_train_scaled,y_train)
y_predict = model.predict(x_test_scaled)

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Hacer predicciones sobre los datos de prueba.
y_pred = model.predict_proba(x_test_scaled)[:,1]

# Calcular el fpr, tpr y los umbrales para la curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Calcular el AUC
roc_auc = roc_auc_score(y_test, y_pred)

# Trazar la curva ROC
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(roc_auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# %%
# usando el informe de clasificación para evaluar el modelo
from sklearn.metrics import classification_report

report = classification_report(y_test,y_predict)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       930
#            1       0.59      0.14      0.22       167
#
#     accuracy                           0.85      1097
#    macro avg       0.73      0.56      0.57      1097
# weighted avg       0.82      0.85      0.81      1097
